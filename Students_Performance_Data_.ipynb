# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeca07-pedrozo/desercionEstudiantil/blob/main/Students_Performance_Data_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import google.colab.drive
google.colab.drive.mount('/content/drive')
file_path = '/content/drive/My Drive/Student_performance_data.csv'
datos = pd.read_csv(file_path, encoding='latin1')
# Out:
# Mounted at /content/drive

# %%
RowsYColums=datos.shape
print(RowsYColums)
# Out:
# (2392, 15)

# %%
missing_data=datos.isna().sum()
print(missing_data)
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
print(datos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB
# None

# %%
datos.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
datos['StudyTimeWeekly']=pd.to_datetime(datos['StudyTimeWeekly'])
print(datos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   datetime64[ns]
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(12)
# ...

# %%
datos['StudyTimeWeekly'].head()
# Out:
# 0   1970-01-01 00:00:00.000000019
# 1   1970-01-01 00:00:00.000000015
# 2   1970-01-01 00:00:00.000000004
# 3   1970-01-01 00:00:00.000000010
# 4   1970-01-01 00:00:00.000000004
# Name: StudyTimeWeekly, dtype: datetime64[ns]

# %%
Description=datos.describe()
print(Description)
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
# std     690.655244     1.123798     0.499986     1.028476           1.000411
#
#                      StudyTimeWeekly     Absences     Tutoring  \
# count                           2392  2392.000000  2392.000000
# mean   1970-01-01 00:00:00.000000009    14.541388     0.301421
# min              1970-01-01 00:00:00     0.000000     0.000000
# ...

# %%
NombresDeColumnas=datos.columns
print(NombresDeColumnas)
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
EdadesEstudiantes=datos['Age']
print(EdadesEstudiantes)
# Out:
# 0       17
# 1       18
# 2       15
# 3       17
# 4       17
#         ..
# 2387    18
# 2388    17
# 2389    16
# 2390    16
# 2391    16
# Name: Age, Length: 2392, dtype: int64

# %%
MedianaEdades=EdadesEstudiantes.median()
print(MedianaEdades)
# Out:
# 16.0

# %%
ZeroToFive=datos.iloc[:5]
print(ZeroToFive)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  \
# 0       1001   17       1          0                  2
# 1       1002   18       0          0                  1
# 2       1003   15       0          2                  3
# 3       1004   17       1          0                  3
# 4       1005   17       1          0                  2
#
#                 StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0 1970-01-01 00:00:00.000000019         7         1                2
# 1 1970-01-01 00:00:00.000000015         0         0                1
# 2 1970-01-01 00:00:00.000000004        26         0                2
# 3 1970-01-01 00:00:00.000000010        14         0                3
# 4 1970-01-01 00:00:00.000000004        17         1                3
#
#    Extracurricular  Sports  Music  Volunteering       GPA  GradeClass
# 0                0       0      1             0  2.929196         2.0
# 1                0       0      0             0  3.042915         1.0
# ...

# %%
subset=datos.iloc[:5, :3]
print(subset)
# Out:
#    StudentID  Age  Gender
# 0       1001   17       1
# 1       1002   18       0
# 2       1003   15       0
# 3       1004   17       1
# 4       1005   17       1

# %%
subset=datos.iloc[4, 0]
print(subset)
# Out:
# 1005

# %%
TimeAndAge=datos.loc[:100, ['Age', 'Gender','StudyTimeWeekly','GradeClass']]
print(TimeAndAge)
# Out:
#      Age  Gender               StudyTimeWeekly  GradeClass
# 0     17       1 1970-01-01 00:00:00.000000019         2.0
# 1     18       0 1970-01-01 00:00:00.000000015         1.0
# 2     15       0 1970-01-01 00:00:00.000000004         4.0
# 3     17       1 1970-01-01 00:00:00.000000010         3.0
# 4     17       1 1970-01-01 00:00:00.000000004         4.0
# ..   ...     ...                           ...         ...
# 96    16       1 1970-01-01 00:00:00.000000012         4.0
# 97    18       0 1970-01-01 00:00:00.000000000         2.0
# 98    16       0 1970-01-01 00:00:00.000000008         4.0
# 99    15       0 1970-01-01 00:00:00.000000017         4.0
# 100   17       1 1970-01-01 00:00:00.000000006         4.0
#
# [101 rows x 4 columns]

# %%
datos['ActivadesAireLibre']= datos['Music'] + datos['Sports'] + datos['Volunteering'] + datos['Extracurricular']
print(datos.head())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  \
# 0       1001   17       1          0                  2
# 1       1002   18       0          0                  1
# 2       1003   15       0          2                  3
# 3       1004   17       1          0                  3
# 4       1005   17       1          0                  2
#
#                 StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0 1970-01-01 00:00:00.000000019         7         1                2
# 1 1970-01-01 00:00:00.000000015         0         0                1
# 2 1970-01-01 00:00:00.000000004        26         0                2
# 3 1970-01-01 00:00:00.000000010        14         0                3
# 4 1970-01-01 00:00:00.000000004        17         1                3
#
#    Extracurricular  Sports  Music  Volunteering       GPA  GradeClass  \
# 0                0       0      1             0  2.929196         2.0
# ...

# %%
datos[['GradeClass','ActivadesAireLibre']].head()
# Out:
#    GradeClass  ActivadesAireLibre
# 0         2.0                   1
# 1         1.0                   0
# 2         4.0                   0
# 3         3.0                   1
# 4         4.0                   0

# %%
datos[['GradeClass', 'ActivadesAireLibre']].iloc[:10, :10]
# Out:
#    GradeClass  ActivadesAireLibre
# 0         2.0                   1
# 1         1.0                   0
# 2         4.0                   0
# 3         3.0                   1
# 4         4.0                   0
# 5         1.0                   1
# 6         2.0                   1
# 7         4.0                   1
# 8         2.0                   2
# 9         0.0                   1

# %%
ActivadesAireLibre_Media = datos['ActivadesAireLibre'].mean()
print(ActivadesAireLibre_Media)
# Out:
# 1.0409698996655519

# %%
datos['NumeroPositivoActividades'] = datos['ActivadesAireLibre'] > 0
print(datos['NumeroPositivoActividades'].head(10))
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: NumeroPositivoActividades, dtype: bool

# %%
datos.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  \
# 0       1001   17       1          0                  2
# 1       1002   18       0          0                  1
# 2       1003   15       0          2                  3
# 3       1004   17       1          0                  3
# 4       1005   17       1          0                  2
#
#                 StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0 1970-01-01 00:00:00.000000019         7         1                2
# 1 1970-01-01 00:00:00.000000015         0         0                1
# 2 1970-01-01 00:00:00.000000004        26         0                2
# 3 1970-01-01 00:00:00.000000010        14         0                3
# 4 1970-01-01 00:00:00.000000004        17         1                3
#
#    Extracurricular  Sports  Music  Volunteering       GPA  GradeClass  \
# 0                0       0      1             0  2.929196         2.0
# ...

# %%
datos['ParentsSupport'] = datos['ParentalSupport'].apply(lambda x: x != 0)
print(datos['ParentsSupport'].head(10))
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: ParentsSupport, dtype: bool

# %%
datos.head(8)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  \
# 0       1001   17       1          0                  2
# 1       1002   18       0          0                  1
# 2       1003   15       0          2                  3
# 3       1004   17       1          0                  3
# 4       1005   17       1          0                  2
# 5       1006   18       0          0                  1
# 6       1007   15       0          1                  1
# 7       1008   15       1          1                  4
#
#                 StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0 1970-01-01 00:00:00.000000019         7         1                2
# 1 1970-01-01 00:00:00.000000015         0         0                1
# 2 1970-01-01 00:00:00.000000004        26         0                2
# 3 1970-01-01 00:00:00.000000010        14         0                3
# 4 1970-01-01 00:00:00.000000004        17         1                3
# ...

# %%
def categoriasNotas(nota):
  if nota >= 90:
    return 'Excelente'
  elif nota >= 80:
    return 'Muy bueno'
  elif nota >= 70:
    return 'Bueno'
  elif nota >= 60:
    return 'Regular'
  else:
    return 'Malo'
datos['CategoriasDeNotas']=datos['GradeClass'].apply(categoriasNotas)
print(datos['CategoriasDeNotas'].head(10))
# Out:
# 0    Malo
# 1    Malo
# 2    Malo
# 3    Malo
# 4    Malo
# 5    Malo
# 6    Malo
# 7    Malo
# 8    Malo
# 9    Malo
# Name: CategoriasDeNotas, dtype: object

# %%
Edades=datos['Age'].value_counts()
print(Edades)
# Out:
# Age
# 15    630
# 16    593
# 17    587
# 18    582
# Name: count, dtype: int64

# %%
AgrupacionEdades=datos.groupby('Age')['Absences'].agg(['mean', 'sum'])
print(AgrupacionEdades)
# Out:
#           mean   sum
# Age
# 15   14.550794  9167
# 16   14.807757  8781
# 17   14.419080  8464
# 18   14.383162  8371

# %%
NotasAltas=datos[datos['GradeClass']>2]
print(NotasAltas)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  \
# 2          1003   15       0          2                  3
# 3          1004   17       1          0                  3
# 4          1005   17       1          0                  2
# 7          1008   15       1          1                  4
# 10         1011   17       0          0                  1
# ...         ...  ...     ...        ...                ...
# 2382       3383   16       0          0                  3
# 2383       3384   16       1          2                  2
# 2384       3385   15       1          0                  1
# 2386       3387   16       0          0                  2
# 2388       3389   17       0          0                  1
#
#                    StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 2    1970-01-01 00:00:00.000000004        26         0                2
# 3    1970-01-01 00:00:00.000000010        14         0                3
# ...

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
HorasDeEstudio=datos['StudyTimeWeekly'].value_counts()
plt.bar(HorasDeEstudio.index, HorasDeEstudio.values)
plt.xlabel('Horas de Estudio')
plt.ylabel('Número de Estudiantes')
plt.title('Distribución de Horas de Estudio')
plt.show()
